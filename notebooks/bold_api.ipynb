# %%
import yaml
with open("../data/raw/bold_api/bold_names.yaml", "r") as f:
    config = yaml.safe_load(f)
config["bold_name"]
# Out:
# ['Agapetus',
#  'Ameletus inopinatus',
#  'Amphinemura borealis',
#  'Baetis rhodani',
#  'Baetis vernus',
#  'Capnopsis schilleri',
#  'Diura',
#  'Elmis aenea',
#  'Ephemerella aurivillii',
#  'Ephemerella mucronata',
#  'Heptagenia sulphurea',
#  'Hydraena',
#  'Hydropsyche pellucidula',
#  'Hydropsyche saxonica',
#  'Hydropsyche siltalai',
#  'Isoperla',
#  'Kageronia fuscogrisea',
#  'Lepidostoma hirtum',
#  'Leptophlebia',
#  'Leuctra nigra',
#  'Leuctra',
#  'Limnius volckmari',
#  'Micrasema gelidum',
#  'Micrasema setiferum',
#  'Nemoura cinerea',
#  'Nemoura',
#  'Neureclipsis bimaculata',
#  'Oulimnius tuberculatus',
#  'Oxyethira',
#  'Plectrocnemia',
#  'Polycentropus flavomaculatus',
#  'Polycentropus irroratus',
#  'Protonemura',
#  'Rhyacophila nubila',
#  'Sialis',
#  'Silo pallipes',
#  'Simuliidae',
#  'Sphaerium',
#  'Taeniopteryx nebulosa']

# %%
from urllib.request import urlretrieve
from pathlib import Path

raw_folder = Path("../data/raw/bold_api")
out_folder = Path("../data/processed/bold_api")

def fetch_bold_sequences(taxon, out_fname):
    url = ("http://v3.boldsystems.org/index.php/API_Public/sequence?"
    f"taxon={taxon.replace(' ', '%20')}"
        "&marker=COI-5P"
        "&format=xml")

    urlretrieve(url, filename=out_fname)
    print(f"loaded '{taxon}'")

taxon = "Sialis"
out_fname = raw_folder / f"{taxon.replace(' ', '_')}.fasta"
fetch_bold_sequences(taxon, out_fname)
# Out:
# loaded 'Sialis'

# %%
for taxon in config["bold_name"]:
    out_fname = raw_folder / f"{taxon.replace(' ', '_')}.fasta"
    fetch_bold_sequences(taxon, out_fname)
# Out:
# loaded 'Agapetus'
# loaded 'Ameletus inopinatus'
# loaded 'Amphinemura borealis'
# loaded 'Baetis rhodani'
# loaded 'Baetis vernus'
# loaded 'Capnopsis schilleri'
# loaded 'Diura'
# loaded 'Elmis aenea'
# loaded 'Ephemerella aurivillii'
# loaded 'Ephemerella mucronata'
# loaded 'Heptagenia sulphurea'
# loaded 'Hydraena'
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 3
#       1 for taxon in config["bold_name"]:
#       2     out_fname = raw_folder / f"{taxon.replace(' ', '_')}.fasta"
# ----> 3     fetch_bold_sequences(taxon, out_fname)
#
# Cell In[2], line 13, in fetch_bold_sequences(taxon, out_fname)
#       7 def fetch_bold_sequences(taxon, out_fname):
#       8     url = ("http://v3.boldsystems.org/index.php/API_Public/sequence?"
#       9     f"taxon={taxon.replace(' ', '%20')}"
#      10         "&marker=COI-5P"
#      11         "&format=xml")
# ---> 13     urlretrieve(url, filename=out_fname)
#      14     print(f"loaded '{taxon}'")
#
# File c:\Users\E1007914\AppData\Local\miniconda3\envs\taxonomist\lib\urllib\request.py:268, in urlretrieve(url, filename, reporthook, data)
#     265     reporthook(blocknum, bs, size)
#     267 while True:
# --> 268     block = fp.read(bs)
#     269     if not block:
#     270         break
#
# File c:\Users\E1007914\AppData\Local\miniconda3\envs\taxonomist\lib\http\client.py:463, in HTTPResponse.read(self, amt)
#     460 if amt is not None:
#     461     # Amount is given, implement using readinto
#     462     b = bytearray(amt)
# --> 463     n = self.readinto(b)
#     464     return memoryview(b)[:n].tobytes()
#     465 else:
#     466     # Amount is not given (unbounded read) so we must check self.length
#     467     # and self.chunked
#
# File c:\Users\E1007914\AppData\Local\miniconda3\envs\taxonomist\lib\http\client.py:497, in HTTPResponse.readinto(self, b)
#     494     return 0
#     496 if self.chunked:
# --> 497     return self._readinto_chunked(b)
#     499 if self.length is not None:
#     500     if len(b) > self.length:
#     501         # clip the read to the "end of response"
#
# File c:\Users\E1007914\AppData\Local\miniconda3\envs\taxonomist\lib\http\client.py:592, in HTTPResponse._readinto_chunked(self, b)
#     590 try:
#     591     while True:
# --> 592         chunk_left = self._get_chunk_left()
#     593         if chunk_left is None:
#     594             return total_bytes
#
# File c:\Users\E1007914\AppData\Local\miniconda3\envs\taxonomist\lib\http\client.py:560, in HTTPResponse._get_chunk_left(self)
#     558     self._safe_read(2)  # toss the CRLF at the end of the chunk
#     559 try:
# --> 560     chunk_left = self._read_next_chunk_size()
#     561 except ValueError:
#     562     raise IncompleteRead(b'')
#
# File c:\Users\E1007914\AppData\Local\miniconda3\envs\taxonomist\lib\http\client.py:520, in HTTPResponse._read_next_chunk_size(self)
#     518 def _read_next_chunk_size(self):
#     519     # Read the next chunk size from the file
# --> 520     line = self.fp.readline(_MAXLINE + 1)
#     521     if len(line) > _MAXLINE:
#     522         raise LineTooLong("chunk size")
#
# File c:\Users\E1007914\AppData\Local\miniconda3\envs\taxonomist\lib\socket.py:704, in SocketIO.readinto(self, b)
#     702 while True:
#     703     try:
# --> 704         return self._sock.recv_into(b)
#     705     except timeout:
#     706         self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
from Bio import SeqIO
from random import sample
from io import StringIO
import pandas as pd
import numpy as np

def preprocess_fasta(input):
    folder = input.parent
    records = [r for r in SeqIO.parse(input, "fasta")]
    print("Original length:", len(records))

    # Find the lengths of sequences and filter too long and short sequences
    lengths = np.asarray([len(r.seq) for r in records])
    filter_ind = np.logical_and((lengths <= 658), (lengths >= 600))
    records_subset0 = [records[i] for i in np.where(filter_ind)[0]]
    print("Sequences between 600 and 658:", len(records_subset0))

    # Remove duplicate sequences
    seen = set()
    records_subset = []
    for r in records_subset0:
        if r.seq not in seen:
            seen.add(r.seq)
            records_subset.append(r)

    print("After duplicates removed:", len(records_subset))

    # Cap the maximum number of sequences to 500
    if len(records_subset) > 200:
        records_subset = sample(records_subset, 200)
        print("Capped to 200:", len(records_subset))

    subset_name = raw_folder / f"{input.stem}_subset.fasta"
    with open(subset_name, "w") as output_handle:
        SeqIO.write(records_subset, output_handle, "fasta")
    print(subset_name)

# %%
import subprocess
for taxon in config["bold_name"]:
    out_fname = raw_folder / f"{taxon.replace(' ', '_')}.fasta"
    preprocess_fasta(out_fname)
# Out:
# Original length: 652
# Sequences between 600 and 658: 596
# After duplicates removed: 359
# Capped to 200: 200
# ..\data\raw\bold_api\Agapetus_subset.fasta
# Original length: 42
# Sequences between 600 and 658: 41
# After duplicates removed: 23
# ..\data\raw\bold_api\Ameletus_inopinatus_subset.fasta
# Original length: 14
# Sequences between 600 and 658: 14
# After duplicates removed: 7
# ..\data\raw\bold_api\Amphinemura_borealis_subset.fasta
# Original length: 588
# Sequences between 600 and 658: 413
# After duplicates removed: 341
# Capped to 200: 200
# ..\data\raw\bold_api\Baetis_rhodani_subset.fasta
# Original length: 159
# Sequences between 600 and 658: 102
# After duplicates removed: 55
# ..\data\raw\bold_api\Baetis_vernus_subset.fasta
# Original length: 13
# Sequences between 600 and 658: 10
# After duplicates removed: 9
# ..\data\raw\bold_api\Capnopsis_schilleri_subset.fasta
# Original length: 74
# Sequences between 600 and 658: 57
# After duplicates removed: 37
# ..\data\raw\bold_api\Diura_subset.fasta
# Original length: 331
# Sequences between 600 and 658: 313
# After duplicates removed: 73
# ..\data\raw\bold_api\Elmis_aenea_subset.fasta
# Original length: 39
# Sequences between 600 and 658: 38
# After duplicates removed: 29
# ..\data\raw\bold_api\Ephemerella_aurivillii_subset.fasta
# Original length: 29
# Sequences between 600 and 658: 23
# After duplicates removed: 17
# ..\data\raw\bold_api\Ephemerella_mucronata_subset.fasta
# Original length: 19
# Sequences between 600 and 658: 18
# After duplicates removed: 17
# ..\data\raw\bold_api\Heptagenia_sulphurea_subset.fasta
# Original length: 300
# Sequences between 600 and 658: 242
# After duplicates removed: 174
# ..\data\raw\bold_api\Hydraena_subset.fasta
# Original length: 12
# Sequences between 600 and 658: 11
# After duplicates removed: 8
# ..\data\raw\bold_api\Hydropsyche_pellucidula_subset.fasta
# Original length: 86
# Sequences between 600 and 658: 78
# After duplicates removed: 19
# ..\data\raw\bold_api\Hydropsyche_saxonica_subset.fasta
# Original length: 105
# Sequences between 600 and 658: 96
# After duplicates removed: 23
# ..\data\raw\bold_api\Hydropsyche_siltalai_subset.fasta
# Original length: 1237
# Sequences between 600 and 658: 965
# After duplicates removed: 709
# Capped to 200: 200
# ..\data\raw\bold_api\Isoperla_subset.fasta
# Original length: 16
# Sequences between 600 and 658: 16
# After duplicates removed: 9
# ..\data\raw\bold_api\Kageronia_fuscogrisea_subset.fasta
# Original length: 93
# Sequences between 600 and 658: 85
# After duplicates removed: 64
# ..\data\raw\bold_api\Lepidostoma_hirtum_subset.fasta
# Original length: 270
# Sequences between 600 and 658: 220
# After duplicates removed: 145
# ..\data\raw\bold_api\Leptophlebia_subset.fasta
# Original length: 75
# Sequences between 600 and 658: 66
# After duplicates removed: 33
# ..\data\raw\bold_api\Leuctra_nigra_subset.fasta
# Original length: 1819
# Sequences between 600 and 658: 1499
# After duplicates removed: 944
# Capped to 200: 200
# ..\data\raw\bold_api\Leuctra_subset.fasta
# Original length: 34
# Sequences between 600 and 658: 33
# After duplicates removed: 18
# ..\data\raw\bold_api\Limnius_volckmari_subset.fasta
# Original length: 5
# Sequences between 600 and 658: 4
# After duplicates removed: 4
# ..\data\raw\bold_api\Micrasema_gelidum_subset.fasta
# Original length: 34
# Sequences between 600 and 658: 25
# After duplicates removed: 19
# ..\data\raw\bold_api\Micrasema_setiferum_subset.fasta
# Original length: 101
# Sequences between 600 and 658: 82
# After duplicates removed: 45
# ..\data\raw\bold_api\Nemoura_cinerea_subset.fasta
# Original length: 848
# Sequences between 600 and 658: 772
# After duplicates removed: 481
# Capped to 200: 200
# ..\data\raw\bold_api\Nemoura_subset.fasta
# Original length: 48
# Sequences between 600 and 658: 35
# After duplicates removed: 17
# ..\data\raw\bold_api\Neureclipsis_bimaculata_subset.fasta
# Original length: 16
# Sequences between 600 and 658: 16
# After duplicates removed: 5
# ..\data\raw\bold_api\Oulimnius_tuberculatus_subset.fasta
# Original length: 562
# Sequences between 600 and 658: 398
# After duplicates removed: 329
# Capped to 200: 200
# ..\data\raw\bold_api\Oxyethira_subset.fasta
# Original length: 616
# Sequences between 600 and 658: 578
# After duplicates removed: 343
# Capped to 200: 200
# ..\data\raw\bold_api\Plectrocnemia_subset.fasta
# Original length: 55
# Sequences between 600 and 658: 53
# After duplicates removed: 25
# ..\data\raw\bold_api\Polycentropus_flavomaculatus_subset.fasta
# Original length: 28
# Sequences between 600 and 658: 20
# After duplicates removed: 11
# ..\data\raw\bold_api\Polycentropus_irroratus_subset.fasta
# Original length: 286
# Sequences between 600 and 658: 230
# After duplicates removed: 164
# ..\data\raw\bold_api\Protonemura_subset.fasta
# Original length: 67
# Sequences between 600 and 658: 65
# After duplicates removed: 35
# ..\data\raw\bold_api\Rhyacophila_nubila_subset.fasta
# Original length: 155
# Sequences between 600 and 658: 110
# After duplicates removed: 86
# ..\data\raw\bold_api\Sialis_subset.fasta
# Original length: 61
# Sequences between 600 and 658: 53
# After duplicates removed: 37
# ..\data\raw\bold_api\Silo_pallipes_subset.fasta
# Original length: 19514
# Sequences between 600 and 658: 15667
# After duplicates removed: 11079
# Capped to 200: 200
# ..\data\raw\bold_api\Simuliidae_subset.fasta
# Original length: 124
# Sequences between 600 and 658: 94
# After duplicates removed: 70
# ..\data\raw\bold_api\Sphaerium_subset.fasta
# Original length: 22
# Sequences between 600 and 658: 21
# After duplicates removed: 14
# ..\data\raw\bold_api\Taeniopteryx_nebulosa_subset.fasta

# %%
def read_records(filename):
    return [r for r in SeqIO.parse(filename, "fasta")]

# %%
for taxon in config["bold_name"]:
    subset_name = raw_folder / f"{taxon.replace(' ', '_')}_subset.fasta"
    align_name = out_folder / f"{subset_name.stem}.afa"
    records = read_records(subset_name)
    print(f"Aligning {taxon}, {len(records)} records")
    subprocess.run([r"..\muscle.exe",
                        "-super5", str(subset_name), 
                        "-output", str(align_name)]
                        )
    print(f"Aligned to file {align_name}")
# Out:
# Aligning Agapetus, 200 records
# Aligned to file ..\data\processed\bold_api\Agapetus_subset.afa
# Aligning Ameletus inopinatus, 23 records
# Aligned to file ..\data\processed\bold_api\Ameletus_inopinatus_subset.afa
# Aligning Amphinemura borealis, 7 records
# Aligned to file ..\data\processed\bold_api\Amphinemura_borealis_subset.afa
# Aligning Baetis rhodani, 200 records
# Aligned to file ..\data\processed\bold_api\Baetis_rhodani_subset.afa
# Aligning Baetis vernus, 55 records
# Aligned to file ..\data\processed\bold_api\Baetis_vernus_subset.afa
# Aligning Capnopsis schilleri, 9 records
# Aligned to file ..\data\processed\bold_api\Capnopsis_schilleri_subset.afa
# Aligning Diura, 37 records
# Aligned to file ..\data\processed\bold_api\Diura_subset.afa
# Aligning Elmis aenea, 73 records
# Aligned to file ..\data\processed\bold_api\Elmis_aenea_subset.afa
# Aligning Ephemerella aurivillii, 29 records
# Aligned to file ..\data\processed\bold_api\Ephemerella_aurivillii_subset.afa
# Aligning Ephemerella mucronata, 17 records
# Aligned to file ..\data\processed\bold_api\Ephemerella_mucronata_subset.afa
# Aligning Heptagenia sulphurea, 17 records
# Aligned to file ..\data\processed\bold_api\Heptagenia_sulphurea_subset.afa
# Aligning Hydraena, 174 records
# Aligned to file ..\data\processed\bold_api\Hydraena_subset.afa
# Aligning Hydropsyche pellucidula, 8 records
# Aligned to file ..\data\processed\bold_api\Hydropsyche_pellucidula_subset.afa
# Aligning Hydropsyche saxonica, 19 records
# Aligned to file ..\data\processed\bold_api\Hydropsyche_saxonica_subset.afa
# Aligning Hydropsyche siltalai, 23 records
# Aligned to file ..\data\processed\bold_api\Hydropsyche_siltalai_subset.afa
# Aligning Isoperla, 200 records
# Aligned to file ..\data\processed\bold_api\Isoperla_subset.afa
# Aligning Kageronia fuscogrisea, 9 records
# Aligned to file ..\data\processed\bold_api\Kageronia_fuscogrisea_subset.afa
# Aligning Lepidostoma hirtum, 64 records
# Aligned to file ..\data\processed\bold_api\Lepidostoma_hirtum_subset.afa
# Aligning Leptophlebia, 145 records
# Aligned to file ..\data\processed\bold_api\Leptophlebia_subset.afa
# Aligning Leuctra nigra, 33 records
# Aligned to file ..\data\processed\bold_api\Leuctra_nigra_subset.afa
# Aligning Leuctra, 200 records
# Aligned to file ..\data\processed\bold_api\Leuctra_subset.afa
# Aligning Limnius volckmari, 18 records
# Aligned to file ..\data\processed\bold_api\Limnius_volckmari_subset.afa
# Aligning Micrasema gelidum, 4 records
# Aligned to file ..\data\processed\bold_api\Micrasema_gelidum_subset.afa
# Aligning Micrasema setiferum, 19 records
# Aligned to file ..\data\processed\bold_api\Micrasema_setiferum_subset.afa
# Aligning Nemoura cinerea, 45 records
# Aligned to file ..\data\processed\bold_api\Nemoura_cinerea_subset.afa
# Aligning Nemoura, 200 records
# Aligned to file ..\data\processed\bold_api\Nemoura_subset.afa
# Aligning Neureclipsis bimaculata, 17 records
# Aligned to file ..\data\processed\bold_api\Neureclipsis_bimaculata_subset.afa
# Aligning Oulimnius tuberculatus, 5 records
# Aligned to file ..\data\processed\bold_api\Oulimnius_tuberculatus_subset.afa
# Aligning Oxyethira, 200 records
# Aligned to file ..\data\processed\bold_api\Oxyethira_subset.afa
# Aligning Plectrocnemia, 200 records
# Aligned to file ..\data\processed\bold_api\Plectrocnemia_subset.afa
# Aligning Polycentropus flavomaculatus, 25 records
# Aligned to file ..\data\processed\bold_api\Polycentropus_flavomaculatus_subset.afa
# Aligning Polycentropus irroratus, 11 records
# Aligned to file ..\data\processed\bold_api\Polycentropus_irroratus_subset.afa
# Aligning Protonemura, 164 records
# Aligned to file ..\data\processed\bold_api\Protonemura_subset.afa
# Aligning Rhyacophila nubila, 35 records
# Aligned to file ..\data\processed\bold_api\Rhyacophila_nubila_subset.afa
# Aligning Sialis, 86 records
# Aligned to file ..\data\processed\bold_api\Sialis_subset.afa
# Aligning Silo pallipes, 37 records
# Aligned to file ..\data\processed\bold_api\Silo_pallipes_subset.afa
# Aligning Simuliidae, 200 records
# Aligned to file ..\data\processed\bold_api\Simuliidae_subset.afa
# Aligning Sphaerium, 70 records
# Aligned to file ..\data\processed\bold_api\Sphaerium_subset.afa
# Aligning Taeniopteryx nebulosa, 14 records
# Aligned to file ..\data\processed\bold_api\Taeniopteryx_nebulosa_subset.afa

# %%
records = []
for taxon in config["bold_name"]:
    subset_name = raw_folder / f"{taxon.replace(' ', '_')}_subset.fasta"
    align_name = out_folder / f"{subset_name.stem}.afa"
    for r in read_records(align_name):
        records.append(r)

with open("../data/processed/fb2.fasta", "w") as output_handle:
    SeqIO.write(records, output_handle, "fasta")
